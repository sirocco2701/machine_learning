# %%
from numpy import sin
from numpy import sqrt
from numpy import arange
from pandas import read_csv
from scipy.optimize import curve_fit
from matplotlib import pyplot
from sklearn.metrics import r2_score

# %%
def objective(x, a, b, g, c, d):
	return a * sin(b - g*x) + c * x**2 + d

# %%
dataframe = read_csv("data.csv", header=None)
data = dataframe.values
x, y = data[:, 0], data[:, 1]

# %%
popt, _ = curve_fit(objective, x, y)
a, b, g, c, d = popt
print(popt)
# Out:
# [-5.86513746  6.42378949  1.01105254  0.00870368  1.59517225]

# %%
pyplot.scatter(x, y)
x_line = arange(min(x), max(x), 0.02)
y_line = objective(x_line, a, b, g, c, d)
#print(x_line)
pyplot.plot(x_line, y_line, '--', color='red')
pyplot.show()

# %%
r2=r2_score(y, objective(x_line, a, b, g, c, d))
r2
# Out:
# 0.7167793473644032
